# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align="center"><font size="5">Supervised Machine Learning: Regression - Final Assignment</font></h1>

# %% [markdown]
# ## Instructions:
#
# In this Assignment, you will demonstrate the data regression skills you have learned by completing this course. You are expected to leverage a wide variety of tools, but also this report should focus on present findings, insights, and next steps. You may include some visuals from your code output, but this report is intended as a summary of your findings, not as a code review.
#
# The grading will center around 5 main points:
#
# 1. Does the report include a section describing the data?
# 2. Does the report include a paragraph detailing the main objective(s) of this analysis?
# 3. Does the report include a section with variations of linear regression models and specifies which one is the model that best suits the main objective(s) of this analysis.
# 4. Does the report include a clear and well-presented section with key findings related to the main objective(s) of the analysis?
# 5. Does the report highlight possible flaws in the model and a plan of action to revisit this analysis with additional data or different predictive modeling techniques?

# %% [markdown]
# ## Import the required libraries

# %% [markdown]
# The following required modules are pre-installed in the Skills Network Labs environment. However if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you will need to install these libraries by removing the `#` sign before `!mamba` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV

# %% [markdown]
# ## Importing the Dataset

# %% [markdown]
# Before you begin, you will need to choose a data set that you feel passionate about. You can brainstorm with your peers about great public data sets using the discussion board in this module.

# %% [markdown]
# Read your chosen dataset into pandas dataframe:

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Chibueze864/IBM_ML_CERTIFICATION_COURSE/main/Supervised%20Learning%20Projects/Final%20Project/all_billionaires_1997_2023.csv')
data.head(20)
# Out:
#     year  month  rank net_worth     last_name            first_name  \
# 0   1997      7   NaN     2.0 B  Sophonpanich                Chatri
# 1   1997      7   NaN     1.8 B     Adulyadej         King Bhumibol
# 2   1998      7   NaN     3.3 B         Safra                Edmond
# 3   1999      7   NaN     1.0 B       Hinduja  Srichand, Gopichand,
# 4   1999      7   NaN     7.1 B       Schwarz                Dieter
# 5   1999      7   NaN     1.3 B  Ardila Lulle                Carlos
# 6   1999      7   NaN     2.9 B         Ebner                Martin
# 7   1999      7   NaN     1.0 B       Cutrale                  Jose
# 8   1999      7   NaN     1.1 B           Lee                 Peter
# 9   1999      7   NaN     1.8 B         Kampf                 Serge
# 10  1999      7   NaN     2.5 B         Safra                Edmond
# 11  2000      7   NaN     1.0 B       Cutrale                  Jose
# 12  2000      7   NaN     1.9 B         Ebner                Martin
# 13  2000      7   NaN     4.5 B        Henkel                   NaN
# 14  2000      7   NaN     2.9 B           Vik             Alexander
# 15  2000      7   NaN     1.2 B          Noda              Masahiro
# 16  2000      7   NaN     1.2 B        Kozuki              Kagemasa
# 17  2000      7   NaN     2.1 B         Kampf                 Serge
# 18  2000      7   0.0     1.4 B          Wada             Shigefumi
# 19  2001      7   1.0    58.7 B         Gates               William
#
#                        full_name  birth_date   age gender  \
# 0   Chatri Sophonpanich & family  1934-02-28  73.0   Male
# 1        King Bhumibol Adulyadej  1927-12-05  69.0   Male
# 2                   Edmond Safra  1932-08-06  65.0   Male
# 3   Srichand & Gopichand Hinduja  1935-11-28   NaN    NaN
# 4                 Dieter Schwarz  1939-09-24  59.0   Male
# 5            Carlos Ardila Lülle  1930-06-04  68.0   Male
# 6                   Martin Ebner  1945-08-01  53.0   Male
# 7              Jose Luis Cutrale  1946-09-17   NaN   Male
# 8                     Lee family         NaN  71.0   Male
# 9                    Serge Kampf  1934-01-01  65.0   Male
# 10                  Edmond Safra  1932-08-06  66.0   Male
# 11             Jose Luis Cutrale  1946-09-17   NaN   Male
# 12                  Martin Ebner  1945-08-01  54.0   Male
# 13              Christoph Henkel  1958-02-11   NaN    NaN
# 14                 Alexander Vik  1955-02-19  45.0   Male
# 15                 Masahiro Noda  1938-08-24  61.0   Male
# 16               Kagemasa Kozuki  1940-11-12  59.0   Male
# 17                   Serge Kampf  1934-01-01  66.0   Male
# 18                Shigefumi Wada  1952-08-30  47.0   Male
# 19                    Bill Gates  1955-10-28  45.0   Male
#
#    country_of_citizenship country_of_residence city_of_residence  \
# 0                Thailand             Thailand           Bangkok
# 1                Thailand                  NaN               NaN
# 2                 Lebanon              Lebanon               NaN
# 3                   India       United Kingdom            London
# 4                 Germany              Germany        Neckarsulm
# 5                Colombia             Colombia            Bogota
# 6             Switzerland          Switzerland             Wilen
# 7                  Brazil               Brazil         Sao Paulo
# 8               Hong Kong            Hong Kong         Hong Kong
# 9                  France                  NaN               NaN
# 10                Lebanon                  NaN               NaN
# 11                 Brazil               Brazil         Sao Paulo
# 12            Switzerland          Switzerland             Wilen
# 13                Germany       United Kingdom            London
# 14                 Norway               Monaco            Monaco
# 15                  Japan                Japan             Tokyo
# 16                  Japan                Japan             Tokyo
# 17                 France                  NaN               NaN
# 18                  Japan                Japan     Nakano, Tokyo
# 19          United States        United States            Medina
#
#           business_category          business_industries organization_name  \
# 0   Finance and Investments  ['Finance and Investments']               NaN
# 1                       NaN                          NaN               NaN
# 2                       NaN                          NaN               NaN
# 3                       NaN                          NaN               NaN
# 4          Fashion & Retail         ['Fashion & Retail']               NaN
# 5         Food and Beverage        ['Food and Beverage']               NaN
# 6   Finance and Investments  ['Finance and Investments']               NaN
# 7         Food and Beverage        ['Food and Beverage']               NaN
# 8                       NaN                          NaN               NaN
# 9                       NaN                          NaN               NaN
# 10                      NaN                          NaN               NaN
# 11        Food and Beverage        ['Food and Beverage']               NaN
# 12  Finance and Investments  ['Finance and Investments']               NaN
# 13         Fashion & Retail         ['Fashion & Retail']               NaN
# 14  Finance and Investments  ['Finance and Investments']               NaN
# 15               Technology               ['Technology']               NaN
# 16               Technology               ['Technology']               NaN
# 17                      NaN                          NaN               NaN
# 18                      NaN                          NaN               NaN
# 19                      NaN               ['Technology']               NaN
#
#    position_in_organization self_made wealth_status
# 0                       NaN     False           NaN
# 1                       NaN     False           NaN
# 2                       NaN      True           NaN
# 3                       NaN     False           NaN
# 4                       NaN      True           NaN
# 5                       NaN      True           NaN
# 6                       NaN     False           NaN
# 7                       NaN      True           NaN
# 8                       NaN     False           NaN
# 9                       NaN     False           NaN
# 10                      NaN      True           NaN
# 11                      NaN      True           NaN
# 12                      NaN     False           NaN
# 13                      NaN     False           NaN
# 14                 Investor     False           NaN
# 15                      NaN      True           NaN
# 16                      NaN      True           NaN
# 17                      NaN      True           NaN
# 18                      NaN      True           NaN
# 19                      NaN     False           NaN

# %% [markdown]
# Once you have selected a data set, you will produce the deliverables listed below and submit them to one of your peers for review. Treat this exercise as an opportunity to produce analysis that are ready to highlight your analytical skills for a senior audience, for example, the Chief Data Officer, or the Head of Analytics at your company.
# Sections required in your report:
#
# *   Main objective of the analysis that specifies whether your model will be focused on prediction or interpretation.
# *   Brief description of the data set you chose and a summary of its attributes.
# *   Brief summary of data exploration and actions taken for data cleaning and feature engineering.
# *   Summary of training at least three linear regression models which should be variations that cover using a simple  linear regression as a baseline, adding polynomial effects, and using a regularization regression. Preferably, all use the same training and test splits, or the same cross-validation method.
# *  A paragraph explaining which of your regressions you recommend as a final model that best fits your needs in terms of accuracy and explainability.
# *  Summary Key Findings and Insights, which walks your reader through the main drivers of your model and insights from your data derived from your linear regression model.
# *  Suggestions for next steps in analyzing this data, which may include suggesting revisiting this model adding specific data features to achieve a better explanation or a better prediction.

# %% [markdown]
# # 1. About the Data

# %% [markdown]
# The "Forbes Billionaires Evolution" dataset provides a comprehensive examination of the financial growth and status of global billionaires from 1997 to 2023. It meticulously chronicles the transformations, both subtle and substantial, in the fortunes of these financial titans over nearly three decades.
#
# The cover image used for this dataset is sourced from Forbes, with the illustration credited to Geoff J. Kim for Forbes.
#
# Content:
# This dataset offers a plethora of valuable information, including:
#
#     Yearly rankings.
#     Net worth details and evolution.
#     Personal details like names, age, gender, and birth dates.
#     Residence details spanning country, city, and citizenship.
#     In-depth business category and industry classifications.
#     Details about affiliations with various organizations, including positions held.
#     Indicators like "self-made" and the current wealth status.

# %% [markdown]
# # 2. Objectives

# %% [markdown]
# My objective is to identify industries and regions with the most billionaire activity and growth. I would like to identify the sectors and geographical locations that produce the most wealth.
# This task is focused on interpreting the data to find out why some industries produce more wealth than others

# %% [markdown]
# ##3. Exploratory Data Analysis

# %% [markdown]
# Check the data types that make up this dataset along with its value distribution and null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31732 entries, 0 to 31731
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      31732 non-null  int64
#  1   month                     31732 non-null  int64
#  2   rank                      31714 non-null  float64
#  3   net_worth                 31732 non-null  object
#  4   last_name                 28043 non-null  object
#  5   first_name                27985 non-null  object
#  6   full_name                 31732 non-null  object
#  7   birth_date                27328 non-null  object
#  8   age                       31057 non-null  float64
#  9   gender                    27903 non-null  object
#  10  country_of_citizenship    31723 non-null  object
#  11  country_of_residence      31030 non-null  object
#  12  city_of_residence         30797 non-null  object
#  13  business_category         25889 non-null  object
#  14  business_industries       30742 non-null  object
#  15  organization_name         4388 non-null   object
#  16  position_in_organization  4692 non-null   object
#  17  self_made                 28043 non-null  object
#  18  wealth_status             24586 non-null  object
# dtypes: float64(2), int64(2), object(15)
# memory usage: 4.6+ MB

# %% [markdown]
# So most of the data types in this data are categorical

# %%
data.describe()
# Out:
#                year         month          rank           age
# count  31732.000000  31732.000000  31714.000000  31057.000000
# mean    2015.755956      3.364143    903.961374     62.835077
# std        5.644194      0.604035    645.565108     14.175068
# min     1997.000000      2.000000      0.000000      0.000000
# 25%     2012.000000      3.000000    366.000000     54.000000
# 50%     2017.000000      3.000000    782.000000     63.000000
# 75%     2021.000000      4.000000   1362.000000     73.000000
# max     2023.000000      7.000000   2674.000000    101.000000

# %%
for col in data.columns:
    value_counts = data[col].value_counts().reset_index()
    value_counts.columns = [col, 'Counts']
    print(f"Value counts for {col}:\n{value_counts}\n")
# Out:
# Value counts for year:
#     year  Counts
# 0   2021    2755
# 1   2022    2668
# 2   2023    2640
# 3   2018    2208
# 4   2019    2153
# 5   2020    2095
# 6   2017    2043
# 7   2015    1826
# 8   2016    1811
# 9   2014    1645
# 10  2013    1426
# 11  2012    1226
# 12  2011    1209
# 13  2010    1011
# 14  2008     908
# 15  2007     761
# 16  2009     738
# 17  2006     628
# 18  2005     530
# 19  2004     432
# 20  2001     335
# 21  2002     333
# 22  2003     332
# 23  2000       8
# 24  1999       8
# 25  1997       2
# 26  1998       1
#
# Value counts for month:
#    month  Counts
# 0      3   21208
# 1      4   10158
# 2      7     347
# 3      2      12
# 4      6       7
#
# Value counts for rank:
#        rank  Counts
# 0    1818.0     234
# 1    1415.0     183
# 2    1513.0     166
# 3    2524.0     150
# 4    1929.0     147
# ..      ...     ...
# 835   781.0       1
# 836   526.0       1
# 837  1152.0       1
# 838  1711.0       1
# 839     0.0       1
#
# [840 rows x 2 columns]
#
# Value counts for net_worth:
#     net_worth  Counts
# 0       1.1 B    1738
# 1       1.2 B    1652
# 2       1.0 B    1593
# 3       1.3 B    1544
# 4       1.5 B    1428
# ..        ...     ...
# 536    46.0 B       1
# 537    45.3 B       1
# 538    42.2 B       1
# 539    38.5 B       1
# 540    25.6 B       1
#
# [541 rows x 2 columns]
#
# Value counts for last_name:
#            last_name  Counts
# 0               Wang     373
# 1                 Li     331
# 2              Zhang     272
# 3               Chen     258
# 4                Lee     209
# ...              ...     ...
# 2588             Sia       1
# 2589       Schnatter       1
# 2590          Mouton       1
# 2591  Lim Siew Choon       1
# 2592           Wolff       1
#
# [2593 rows x 2 columns]
#
# Value counts for first_name:
#        first_name  Counts
# 0            John     507
# 1           David     426
# 2         Michael     329
# 3          Thomas     270
# 4         Richard     252
# ...           ...     ...
# 2919     Liaoyuan       1
# 2920   Banwarilal       1
# 2921  Girdharilal       1
# 2922    Manfredi        1
# 2923    Bingzheng       1
#
# [2924 rows x 2 columns]
#
# Value counts for full_name:
#                    full_name  Counts
# 0              Robert Miller      27
# 1                Craig McCaw      23
# 2                  Ty Warner      23
# 3              Thomas Siebel      23
# 4             Leonard Lauder      23
# ...                      ...     ...
# 4977         Wong Chiu Yeung       1
# 4978              Tao Yuequn       1
# 4979      Li Xianyu & family       1
# 4980             Linden Blue       1
# 4981  Xie Bingzheng & family       1
#
# [4982 rows x 2 columns]
#
# Value counts for birth_date:
#       birth_date  Counts
# 0     1962-01-01     167
# 1     1951-01-01     145
# 2     1964-01-01     140
# 3     1954-01-01     130
# 4     1955-01-01     127
# ...          ...     ...
# 3108  1932-02-01       1
# 3109  1963-04-27       1
# 3110  1952-11-21       1
# 3111  1972-11-23       1
# 3112  1940-12-15       1
#
# [3113 rows x 2 columns]
#
# Value counts for age:
#       age  Counts
# 0    59.0     869
# 1    58.0     868
# 2    65.0     857
# 3    60.0     852
# 4    57.0     846
# ..    ...     ...
# 80  100.0       4
# 81   19.0       4
# 82   20.0       4
# 83  101.0       4
# 84   18.0       3
#
# [85 rows x 2 columns]
#
# Value counts for gender:
#    gender  Counts
# 0    Male   24868
# 1  Female    3035
#
# Value counts for country_of_citizenship:
#    country_of_citizenship  Counts
# 0           United States   10142
# 1                   China    4162
# 2                 Germany    1688
# 3                  Russia    1584
# 4                   India    1485
# ..                    ...     ...
# 83              Guatemala       1
# 84               Pakistan       1
# 85                  Macao       1
# 86             Bangladesh       1
# 87                 Panama       1
#
# [88 rows x 2 columns]
#
# Value counts for country_of_residence:
#    country_of_residence  Counts
# 0         United States   10058
# 1                 China    4389
# 2                Russia    1411
# 3                 India    1362
# 4               Germany    1356
# ..                  ...     ...
# 89             Pakistan       1
# 90        Hong Kong SAR       1
# 91           Uzbekistan       1
# 92               Latvia       1
# 93           Luxembourg       1
#
# [94 rows x 2 columns]
#
# Value counts for city_of_residence:
#       city_of_residence  Counts
# 0              New York    1368
# 1                Moscow    1162
# 2             Hong Kong     985
# 3                London     846
# 4               Beijing     704
# ...                 ...     ...
# 1133     Newtown Square       1
# 1134          Nuremberg       1
# 1135  Santiago de Chile       1
# 1136             Kanpur       1
# 1137            Arcadia       1
#
# [1138 rows x 2 columns]
#
# Value counts for business_category:
#              business_category  Counts
# 0                   Technology    2610
# 1             Fashion & Retail    2446
# 2                Manufacturing    2386
# 3                  Real Estate    2208
# 4                  Diversified    1950
# 5      Finance and Investments    1756
# 6                   Healthcare    1528
# 7        Finance & Investments    1472
# 8                       Energy    1183
# 9            Food and Beverage    1147
# 10                     Service     832
# 11             Food & Beverage     806
# 12       Media & Entertainment     780
# 13             Metals & Mining     740
# 14                 Investments     663
# 15                  Automotive     595
# 16  Construction & Engineering     548
# 17                   Logistics     404
# 18                     Telecom     342
# 19                      Sports     321
# 20                       Media     275
# 21          Fashion and Retail     245
# 22          Gambling & Casinos     238
# 23                 Health care     104
# 24                     Finance      93
# 25                      Retail      38
# 26                      Gaming      35
# 27            Service & Retail      30
# 28                    Business      22
# 29                 Billionaire      22
# 30        Food & Manufacturing      16
# 31       Technology & Medicine      13
# 32                         Oil      11
# 33             All Star Alumni       8
# 34                    Medicine       7
# 35                   Celebrity       6
# 36                    Politics       5
# 37                       Games       1
# 38        Social Entrepreneurs       1
# 39       Technology / Business       1
# 40          Retail & Ecommerce       1
#
# Value counts for business_industries:
#          business_industries  Counts
# 0          ['Manufacturing']    2818
# 1             ['Technology']    2682
# 2            ['Real Estate']    2621
# 3       ['Fashion & Retail']    2464
# 4            ['Diversified']    2155
# ..                       ...     ...
# 62  ['Hotels &#38; Resorts']       2
# 63         ['Biotechnology']       1
# 64                  ['Coal']       1
# 65                 ['Banks']       1
# 66        ['Transportation']       1
#
# [67 rows x 2 columns]
#
# Value counts for organization_name:
#                    organization_name  Counts
# 0                           Facebook      39
# 1                                Gap      34
# 2    Kingston Technology Corporation      32
# 3                      SAS Institute      32
# 4                      Carlyle Group      32
# ..                               ...     ...
# 562            Las Vegas Sands Corp.       1
# 563                   JPMorgan Chase       1
# 564                           NCSOFT       1
# 565                     Db Insurance       1
# 566                              NBA       1
#
# [567 rows x 2 columns]
#
# Value counts for position_in_organization:
#                               position_in_organization  Counts
# 0                                         Entrepreneur     561
# 1                                             Chairman     510
# 2                                     Chairman and CEO     447
# 3                                              Founder     438
# 4                                             Investor     415
# ..                                                 ...     ...
# 159                                  Founder and Chair       1
# 160                                  Director Emeritus       1
# 161  Actress, Director/Producer, Entrepreneur, Pers...       1
# 162  Director/Producer, Entrepreneur, Personality, ...       1
# 163                                Executive Chairman        1
#
# [164 rows x 2 columns]
#
# Value counts for self_made:
#    self_made  Counts
# 0       True   17623
# 1      False   10420
#
# Value counts for wealth_status:
#       wealth_status  Counts
# 0         Increased   12367
# 1         Decreased    8438
# 2     Remained Even    2733
# 3  Returned to List    1048

# %% [markdown]
# Here I see that ordinal encoding will not work for most of the categorical columns because the sheer number of categories.

# %% [markdown]
# Check for null values

# %%
data.isna().sum()
# Out:
# year                            0
# month                           0
# rank                           18
# net_worth                       0
# last_name                    3689
# first_name                   3747
# full_name                       0
# birth_date                   4404
# age                           675
# gender                       3829
# country_of_citizenship          9
# country_of_residence          702
# city_of_residence             935
# business_category            5843
# business_industries           990
# organization_name           27344
# position_in_organization    27040
# self_made                    3689
# wealth_status                7146
# dtype: int64

# %%
# Calculate percentage of null values for each feature
null_percentages = (data.isna().sum() / len(data)) * 100

# Print the results
print("Percentage of null values for each feature: \n {}".format(null_percentages) )
# Out:
# Percentage of null values for each feature:
#  year                         0.000000
# month                        0.000000
# rank                         0.056725
# net_worth                    0.000000
# last_name                   11.625488
# first_name                  11.808269
# full_name                    0.000000
# birth_date                  13.878734
# age                          2.127190
# gender                      12.066683
# country_of_citizenship       0.028363
# country_of_residence         2.212278
# city_of_residence            2.946552
# business_category           18.413589
# business_industries          3.119879
# organization_name           86.171688
# position_in_organization    85.213664
# self_made                   11.625488
# wealth_status               22.519854
# dtype: float64

# %% [markdown]
# Remove features with a high ratio of null values with any 16% (0.16) as the threshold

# %%
columns_filtered = null_percentages[null_percentages.values < 15].keys()
columns_filtered = list(columns_filtered)

data_filtered = data[columns_filtered]
data_filtered.head()
# Out:
#    year  month  rank net_worth     last_name            first_name  \
# 0  1997      7   NaN     2.0 B  Sophonpanich                Chatri
# 1  1997      7   NaN     1.8 B     Adulyadej         King Bhumibol
# 2  1998      7   NaN     3.3 B         Safra                Edmond
# 3  1999      7   NaN     1.0 B       Hinduja  Srichand, Gopichand,
# 4  1999      7   NaN     7.1 B       Schwarz                Dieter
#
#                       full_name  birth_date   age gender  \
# 0  Chatri Sophonpanich & family  1934-02-28  73.0   Male
# 1       King Bhumibol Adulyadej  1927-12-05  69.0   Male
# 2                  Edmond Safra  1932-08-06  65.0   Male
# 3  Srichand & Gopichand Hinduja  1935-11-28   NaN    NaN
# 4                Dieter Schwarz  1939-09-24  59.0   Male
#
#   country_of_citizenship country_of_residence city_of_residence  \
# 0               Thailand             Thailand           Bangkok
# 1               Thailand                  NaN               NaN
# 2                Lebanon              Lebanon               NaN
# 3                  India       United Kingdom            London
# 4                Germany              Germany        Neckarsulm
#
#            business_industries self_made
# 0  ['Finance and Investments']     False
# 1                          NaN     False
# 2                          NaN      True
# 3                          NaN     False
# 4         ['Fashion & Retail']      True

# %% [markdown]
# Select the apprioprate features for our task. As I stated above my goal is to identify industries and regions with the most billionaire activity and growth.
#
# We are only concerned about the industries and geographical locations that produce the most wealth so our features of interest are
#
# 1. Net Worth
# 2. Country Of Citizenship
# 3. Country of Residence
# 4. Business Industries
# 5. Year

# %%
columns_of_interest = ["year","net_worth", "country_of_residence", "business_industries"]
data_interest = data[columns_of_interest]
data_interest.columns
# Out:
# Index(['year', 'net_worth', 'country_of_residence', 'business_industries'], dtype='object')

# %% [markdown]
# Fill Null Values

# %%
# Calculate percentage of null values for each feature
null_percentages = (data_interest.isna().sum() / len(data)) * 100

# Print the results
print("Percentage of null values for each feature: \n {}".format(null_percentages) )
# Out:
# Percentage of null values for each feature:
#  year                    0.000000
# net_worth               0.000000
# country_of_residence    2.212278
# business_industries     3.119879
# dtype: float64

# %%
data_interest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31732 entries, 0 to 31731
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  31732 non-null  int64
#  1   net_worth             31732 non-null  object
#  2   country_of_residence  31030 non-null  object
#  3   business_industries   30742 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 991.8+ KB

# %% [markdown]
# Get numeric part of *net_worth* feature. For every number extracted, put it in a new column called *net_worth_billions* that will replace the *net_worth* column

# %%
data_interest['net_worth_billions'] = data_interest['net_worth'].apply(lambda x: ''.join(char for char in x if char.isdigit()))

data_interest = data_interest.drop("net_worth", axis="columns")
# Out:
# <ipython-input-232-026f8e3599c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_interest['net_worth_billions'] = data_interest['net_worth'].apply(lambda x: ''.join(char for char in x if char.isdigit()))

# %%
data_interest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31732 entries, 0 to 31731
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  31732 non-null  int64
#  1   country_of_residence  31030 non-null  object
#  2   business_industries   30742 non-null  object
#  3   net_worth_billions    31732 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 991.8+ KB

# %% [markdown]
# Fill the null values in the dataframe

# %%
for col in data_interest.columns:
  # Calculate the most common value in the column
  most_common_value = data_interest[col].mode()[0]

  # Replace missing values with the most common value
  data_interest[col] = data_interest[col].fillna(most_common_value)

# %%
# Calculate percentage of null values for each feature
null_percentages = (data_interest.isna().sum() / len(data)) * 100

# Print the results
print("Percentage of null values for each feature: \n {}".format(null_percentages) )
# Out:
# Percentage of null values for each feature:
#  year                    0.0
# country_of_residence    0.0
# business_industries     0.0
# net_worth_billions      0.0
# dtype: float64

# %%
data_interest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31732 entries, 0 to 31731
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  31732 non-null  int64
#  1   country_of_residence  31732 non-null  object
#  2   business_industries   31732 non-null  object
#  3   net_worth_billions    31732 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 991.8+ KB

# %%
data_interest.nunique()
# Out:
# year                     27
# country_of_residence     94
# business_industries      67
# net_worth_billions      518
# dtype: int64

# %% [markdown]
# target encode all columns using the year column as the category

# %%
net_worth_billions = data_interest["net_worth_billions"]
for col in data_interest.columns:
    if col != "year" or col != "net_worth_billions":
      # Calculate mean target value for each category
      target_means = data_interest.groupby(col)["year"].mean()

      # Map target means to the categorical column
      data_interest[col] = data_interest[col].map(target_means)

data_interest["net_worth_billions"] = net_worth_billions

data_interest.nunique()
# Out:
# year                     27
# country_of_residence     84
# business_industries      54
# net_worth_billions      518
# dtype: int64

# %%
data_interest.head()
# Out:
#      year  country_of_residence  business_industries net_worth_billions
# 0  1997.0           2017.760000          2016.167039                 20
# 1  1997.0           2014.613290          2013.963498                 18
# 2  1998.0           2014.348837          2013.963498                 33
# 3  1999.0           2015.385289          2013.963498                 10
# 4  1999.0           2015.575959          2018.320617                 71

# %% [markdown]
# # 3. Linear Regression Models

# %% [markdown]
# Pipeline for each model

# %%
# Create a pipeline for Linear Regression
linear_pipeline = Pipeline([
    ('polynomial_features', PolynomialFeatures(degree=2)),
    ('scaler', StandardScaler()),
    ('linear_regression', LinearRegression())
])

# %%
# Create a pipeline for Ridge Regression
ridge_pipeline = Pipeline([
    ('polynomial_features', PolynomialFeatures(degree=2)),
    ('scaler', StandardScaler()),
    ('ridge_regression', Ridge(alpha=1.0))
])

# %%
# Create a pipeline for Lasso Regression
lasso_pipeline = Pipeline([
    ('polynomial_features', PolynomialFeatures(degree=2)),
    ('scaler', StandardScaler()),
    ('lasso_regression', Lasso(alpha=1.0))
])

# %%
# Create a pipeline for Elastic Net with Polynomial Features and Standard Scaler
elastic_net_pipeline = Pipeline([
    ('polynomial_features', PolynomialFeatures(degree=2)),
    ('scaler', StandardScaler()),
    ('elastic_net', ElasticNet())  # No hyperparameters set here
])

# Parameters for grid search
param_grid = {
    'elastic_net__alpha': [0.1, 1.0],
    'elastic_net__l1_ratio': [0.2, 0.5, 0.8]
}

# Perform grid search and cross-validation
grid_search = GridSearchCV(elastic_net_pipeline, param_grid, cv=5)
grid_search.fit(X, y)

# Print best parameters and score
print("Best Parameters:", grid_search.best_params_)
# print("Best Cross-Validation Score:", grid_search.best_score_)
print("Feature Model:", grid_search.best_estimator_)

best_enet = grid_search.best_estimator_["elastic_net"]
best_enet.fit(X,y)
best_enet.coef_
best_enet.score(X,y)
# Out:
# Best Parameters: {'elastic_net__alpha': 0.1, 'elastic_net__l1_ratio': 0.2}
# Feature Model: Pipeline(steps=[('polynomial_features', PolynomialFeatures()),
#                 ('scaler', StandardScaler()),
#                 ('elastic_net', ElasticNet(alpha=0.1, l1_ratio=0.2))])
# 0.43696926431409566

# %%
X = data_interest.drop("business_industries", axis="columns")
y = data_interest["business_industries"]

# %%
# List of pipelines
pipelines = [
    ('Linear Regression', linear_pipeline),
    ('Ridge Regression', ridge_pipeline),
    ('Lasso Regression', lasso_pipeline),
    ('Elastic Net', elastic_net_pipeline)
]

param_grid = {
    'polynomial_features__degree': [1, 2],
    'ridge_regression__alpha': [0.1, 1.0],
    'lasso_regression__alpha': [0.1, 1.0],
    'elastic_net__alpha': [0.1, 1.0],
    'elastic_net__l1_ratio': [0.2, 0.5, 0.8]
}


# Perform grid search and cross-validation
results = []
for name, pipeline in pipelines:
    grid_search = GridSearchCV(pipeline, param_grid, cv=5)
    grid_search.fit(X, y)
    best_params = grid_search.best_params_
    best_score = grid_search.best_score_
    coefs = grid_search.best_estimator_['linear_regression'].coef_
    results.append((name, best_params, best_score, coefs))

# Print results
for name, coefs, score in results:
    print(f"Model: {name}")
    print(f"Score: {score}")
    print(f"Feature Coefficients: {coefs}")
    print("="*40)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-261-9040de17a137> in <cell line: 20>()
#      20 for name, pipeline in pipelines:
#      21     grid_search = GridSearchCV(pipeline, param_grid, cv=5)
# ---> 22     grid_search.fit(X, y)
#      23     best_params = grid_search.best_params_
#      24     best_score = grid_search.best_score_
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     672             cloned_parameters[k] = clone(v, safe=False)
#     673
# --> 674         estimator = estimator.set_params(**cloned_parameters)
#     675
#     676     start_time = time.time()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in set_params(self, **kwargs)
#     209             Pipeline class instance.
#     210         """
# --> 211         self._set_params("steps", **kwargs)
#     212         return self
#     213
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/metaestimators.py in _set_params(self, attr, **params)
#      68
#      69         # 3. Step parameters and other initialisation arguments
# ---> 70         super().set_params(**params)
#      71         return self
#      72
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in set_params(self, **params)
#     203             if key not in valid_params:
#     204                 local_valid_params = self._get_param_names()
# --> 205                 raise ValueError(
#     206                     f"Invalid parameter {key!r} for estimator {self}. "
#     207                     f"Valid parameters are: {local_valid_params!r}."
#
# ValueError: Invalid parameter 'elastic_net' for estimator Pipeline(steps=[('polynomial_features', PolynomialFeatures()),
#                 ('scaler', StandardScaler()),
#                 ('linear_regression', LinearRegression())]). Valid parameters are: ['memory', 'steps', 'verbose'].

# %% [markdown]
# # 4. Insights and key findings

# %% [markdown]
# # 5. Next Steps

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
